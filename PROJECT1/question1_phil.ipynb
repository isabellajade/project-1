# %% [markdown]
# What are the best locations by review category (accuracy, cleanliness, checkin, communication, location, and value)?

# %%
# import dependencies 
import pandas as pd
import numpy as np
import hvplot.pandas
import matplotlib.pyplot as plt

# %%
# read combined csv
combined_df = pd.read_csv('resources/combined_data.csv')

# reduce data to only locations with hot tubs
hot_tubs_df = combined_df[combined_df['has_hot_tub'] == True]
hot_tubs_df.head()
# Out:
#     Unnamed: 0.1  Unnamed: 0     id last_scraped  host_id host_is_superhost  \
# 6              6           6   2708   2022-09-10     3008                 t
# 22            22          22   6931   2022-09-10     3008                 t
# 27            27          27   7992   2022-09-10    22363                 t
# 32            32          32  65467   2022-09-10    61864                 f
# 35            35          35  67089   2022-09-10   210344                 t
#
#    neighbourhood_cleansed   latitude   longitude        room_type  ...  \
# 6               Hollywood  34.096250 -118.346050     Private room  ...
# 22              Hollywood  34.094903 -118.347658     Private room  ...
# 27        Atwater Village  34.113640 -118.260680  Entire home/apt  ...
# 32            Culver City  34.024380 -118.383740     Private room  ...
# 35            Culver City  34.009850 -118.407980  Entire home/apt  ...
#
#     number_of_reviews  last_review review_scores_accuracy  \
# ...

# %%
# get the average review of each category
avg_accuracy = hot_tubs_df['review_scores_accuracy'].mean()
avg_location = hot_tubs_df['review_scores_location'].mean()
avg_cleanliness = hot_tubs_df['review_scores_cleanliness'].mean()
avg_checkin = hot_tubs_df['review_scores_checkin'].mean()
avg_communication = hot_tubs_df['review_scores_communication'].mean()
avg_value = hot_tubs_df['review_scores_value'].mean()

print(np.round(avg_accuracy, decimals=1))
print(np.round(avg_location, decimals=1))
print(np.round(avg_cleanliness, decimals=1))
print(np.round(avg_checkin, decimals=1))
print(np.round(avg_communication, decimals=1))
print(np.round(avg_value, decimals=1))

y_axis_ratings = [avg_accuracy, avg_location, avg_cleanliness, avg_checkin, avg_communication, avg_value]
x_axis = [1, 2, 3, 4, 5, 6]
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,5))
plt.xticks(tick_locations, ["Accuracy", "Location", "Cleanliness", "Check In", "Communication", "Value"])

plt.bar(x_axis, y_axis_ratings, color='r', alpha=0.5, align="center")
# Out:
# 4.8
# 4.9
# 4.8
# 4.9
# 4.9
# 4.7
# <BarContainer object of 6 artists>

# %%
# get the average review of each category to 3 decimal places to zoom into the 4-star ratings (ENHANCE!)
avg_accuracy = hot_tubs_df['review_scores_accuracy'].mean()
avg_location = hot_tubs_df['review_scores_location'].mean()
avg_cleanliness = hot_tubs_df['review_scores_cleanliness'].mean()
avg_checkin = hot_tubs_df['review_scores_checkin'].mean()
avg_communication = hot_tubs_df['review_scores_communication'].mean()
avg_value = hot_tubs_df['review_scores_value'].mean()

print(np.round(avg_accuracy, decimals=3))
print(np.round(avg_location, decimals=3))
print(np.round(avg_cleanliness, decimals=3))
print(np.round(avg_checkin, decimals=3))
print(np.round(avg_communication, decimals=3))
print(np.round(avg_value, decimals=3))

y_axis_ratings = [avg_accuracy, avg_location, avg_cleanliness, avg_checkin, avg_communication, avg_value]
x_axis = [1, 2, 3, 4, 5, 6]
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,5))
plt.xticks(tick_locations, ["Accuracy", "Location", "Cleanliness", "Check In", "Communication", "Value"])
plt.ylim(4.0, 5.0)

plt.bar(x_axis, y_axis_ratings, color='r', alpha=0.5, align="center")
# Out:
# 4.829
# 4.866
# 4.782
# 4.869
# 4.877
# 4.739
# <BarContainer object of 6 artists>

# %%
# get the average review of each category to 5 decimal places to zoom into the 4-star ratings (NEEDS MOAR ENHANCE!)

avg_accuracy = hot_tubs_df['review_scores_accuracy'].mean()
avg_location = hot_tubs_df['review_scores_location'].mean()
avg_cleanliness = hot_tubs_df['review_scores_cleanliness'].mean()
avg_checkin = hot_tubs_df['review_scores_checkin'].mean()
avg_communication = hot_tubs_df['review_scores_communication'].mean()
avg_value = hot_tubs_df['review_scores_value'].mean()

print(np.round(avg_accuracy, decimals=5))
print(np.round(avg_location, decimals=5))
print(np.round(avg_cleanliness, decimals=5))
print(np.round(avg_checkin, decimals=5))
print(np.round(avg_communication, decimals=5))
print(np.round(avg_value, decimals=5))

y_axis_ratings = [avg_accuracy, avg_location, avg_cleanliness, avg_checkin, avg_communication, avg_value]
x_axis = [1, 2, 3, 4, 5, 6]
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,5))
plt.xticks(tick_locations, ["Accuracy", "Location", "Cleanliness", "Check In", "Communication", "Value"])
plt.ylim(4.73, 4.89)

plt.bar(x_axis, y_axis_ratings, color='r', alpha=0.5, align="center")
# Out:
# 4.82893
# 4.86609
# 4.78165
# 4.86946
# 4.87662
# 4.73922
# <BarContainer object of 6 artists>

# %%
# get the count of 1, 2, 3, 4, and 5 star ratings for ACCURACY
num_accuracy = hot_tubs_df['review_scores_accuracy'].count()

one_star_accuracy_df = hot_tubs_df[(hot_tubs_df['review_scores_accuracy'] >= 0) & (hot_tubs_df['review_scores_accuracy'] < 1)].count()
num_1star_accuracy = one_star_accuracy_df['review_scores_accuracy']

two_star_accuracy_df = hot_tubs_df[(hot_tubs_df['review_scores_accuracy'] >= 1) & (hot_tubs_df['review_scores_accuracy'] < 2)].count()
num_2star_accuracy = two_star_accuracy_df['review_scores_accuracy']

three_star_accuracy_df = hot_tubs_df[(hot_tubs_df['review_scores_accuracy'] >= 2) & (hot_tubs_df['review_scores_accuracy'] < 3)].count()
num_3star_accuracy = three_star_accuracy_df['review_scores_accuracy']

four_star_accuracy_df = hot_tubs_df[(hot_tubs_df['review_scores_accuracy'] >= 3) & (hot_tubs_df['review_scores_accuracy'] < 4)].count()
num_4star_accuracy = four_star_accuracy_df['review_scores_accuracy']

five_star_accuracy_df = hot_tubs_df[(hot_tubs_df['review_scores_accuracy'] >= 4) & (hot_tubs_df['review_scores_accuracy'] <= 5)].count()
num_5star_accuracy = five_star_accuracy_df['review_scores_accuracy']


print(num_1star_accuracy)
print(num_2star_accuracy)
print(num_3star_accuracy)
print(num_4star_accuracy)
print(num_5star_accuracy)
# Out:
# 0
# 8
# 9
# 92
# 5893

# %%
# reduce data to 5-star reviews for ACCURACY
five_star_accuracy_df = hot_tubs_df.loc[(hot_tubs_df['review_scores_accuracy'] == 5)].reset_index()
num_five_star_accuracy_locations = five_star_accuracy_df['id'].count()

# full map of 5-star reviews for ACCURACY
five_star_accuracy_map = five_star_accuracy_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.5,
    color = "neighbourhood_cleansed", 
    title = f"5-Stars for Accuracy: {num_five_star_accuracy_locations} Locations"
)

# Display the map plot
five_star_accuracy_map
# Out:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
# reduce data to 5-star reviews for LOCATION
five_star_location_df = hot_tubs_df.loc[(hot_tubs_df['review_scores_location'] == 5)].reset_index()
num_five_star_location_locations = five_star_location_df['id'].count()

# full map of 5-star reviews for LOCATION
five_star_location_map = five_star_location_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.5,
    color = "neighbourhood_cleansed", 
    title = f"5-Stars for Location: {num_five_star_location_locations} Locations"
)

# Display the map plot
five_star_location_map
# Out:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
# reduce data to 5-star reviews for CLEANLINESS
five_star_cleanliness_df = hot_tubs_df.loc[(hot_tubs_df['review_scores_cleanliness'] == 5)].reset_index()
num_five_star_cleanliness_locations = five_star_cleanliness_df['id'].count()

# full map of 5-star reviews for CLEANLINESS
five_star_cleanliness_map = five_star_cleanliness_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.5,
    color = "neighbourhood_cleansed", 
    title = f"5-Stars for Cleanliness: {num_five_star_cleanliness_locations} Locations"
)

# Display the map plot
five_star_cleanliness_map
# Out:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
# reduce data to 5-star reviews for CHECKIN
five_star_checkin_df = hot_tubs_df.loc[(hot_tubs_df['review_scores_checkin'] == 5)].reset_index()
num_five_star_checkin_locations = five_star_checkin_df['id'].count()

# full map of 5-star reviews for CHECKIN
five_star_checkin_map = five_star_checkin_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.5,
    color = "neighbourhood_cleansed", 
    title = f"5-Stars for Check In: {num_five_star_checkin_locations} Locations"
)

# Display the map plot
five_star_checkin_map
# Out:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
# reduce data to 5-star reviews for COMMUNICATION
five_star_communication_df = hot_tubs_df.loc[(hot_tubs_df['review_scores_communication'] == 5)].reset_index()
num_five_star_communication_locations = five_star_communication_df['id'].count()

# full map of 5-star reviews for COMMUNICATION
five_star_communication_map = five_star_communication_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.5,
    color = "neighbourhood_cleansed", 
    title = f"5-Stars for Communication: {num_five_star_communication_locations} Locations"
)

# Display the map plot
five_star_communication_map
# Out:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
# reduce data to 5-star reviews for VALUE
five_star_value_df = hot_tubs_df.loc[(hot_tubs_df['review_scores_value'] == 5)].reset_index()
num_five_star_value_locations = five_star_value_df['id'].count()

# full map of 5-star reviews for VALUE
five_star_value_map = five_star_value_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.5,
    color = "neighbourhood_cleansed", 
    title = f"5-Stars for Value: {num_five_star_value_locations} Locations"
)

# Display the map plot
five_star_value_map
# Out:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/philipjaques/opt/anaconda3/lib/python3.9/site-packages/cartopy/crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...
